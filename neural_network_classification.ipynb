# %% [markdown]
# <a href="https://colab.research.google.com/github/Joniald/Colaboratory/blob/main/neural_network_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Binary classification

# %%
from sklearn.datasets import make_circles

# %%
n_samples = 1000
x, y = make_circles(n_samples=n_samples, noise=0.05, random_state=42)

# %%
import matplotlib.pyplot as plt
print(x[:,0].shape, y.shape)
plt.scatter(x[:,0], x[:,1], marker='.', c=y)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# (1000,) (1000,)
# Text(0, 0.5, 'y')

# %%
import tensorflow as tf

# %%
X_train = x[:800]
X_test = x[800:]
Y_train = y[:800]
Y_test = y[800:]
X_train.shape, Y_train.shape
# Out:
# ((800, 2), (800,))

# %%
tf.random.set_seed(42)

model_01 = tf.keras.Sequential([
    tf.keras.layers.Dense(50, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid'),
])

model_01.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.01),
    metrics = ['accuracy']
) 

history = model_01.fit(X_train, Y_train, epochs=50)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6951 - accuracy: 0.4762
# Epoch 2/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6777 - accuracy: 0.6137
# Epoch 3/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6573 - accuracy: 0.6162
# Epoch 4/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6322 - accuracy: 0.7375
# Epoch 5/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6039 - accuracy: 0.7225
# Epoch 6/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5654 - accuracy: 0.8575
# Epoch 7/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5263 - accuracy: 0.8938
# Epoch 8/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4928 - accuracy: 0.8687
# Epoch 9/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4476 - accuracy: 0.9187
# Epoch 10/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4022 - accuracy: 0.9488
# Epoch 11/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3687 - accuracy: 0.9463
# Epoch 12/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3428 - accuracy: 0.9287
# Epoch 13/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3099 - accuracy: 0.9500
# Epoch 14/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2862 - accuracy: 0.9600
# Epoch 15/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2613 - accuracy: 0.9550
# Epoch 16/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2435 - accuracy: 0.9650
# Epoch 17/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2238 - accuracy: 0.9625
# Epoch 18/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2140 - accuracy: 0.9712
# Epoch 19/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2020 - accuracy: 0.9700
# Epoch 20/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1949 - accuracy: 0.9638
# Epoch 21/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1832 - accuracy: 0.9650
# Epoch 22/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1722 - accuracy: 0.9700
# Epoch 23/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1660 - accuracy: 0.9675
# Epoch 24/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1652 - accuracy: 0.9575
# Epoch 25/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1583 - accuracy: 0.9588
# Epoch 26/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1486 - accuracy: 0.9638
# Epoch 27/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1395 - accuracy: 0.9762
# Epoch 28/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1415 - accuracy: 0.9750
# Epoch 29/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1361 - accuracy: 0.9625
# Epoch 30/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1366 - accuracy: 0.9663
# Epoch 31/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1369 - accuracy: 0.9638
# Epoch 32/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1306 - accuracy: 0.9638
# Epoch 33/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1202 - accuracy: 0.9700
# Epoch 34/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1145 - accuracy: 0.9712
# Epoch 35/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1131 - accuracy: 0.9700
# Epoch 36/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1131 - accuracy: 0.9725
# Epoch 37/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1114 - accuracy: 0.9700
# Epoch 38/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1063 - accuracy: 0.9750
# Epoch 39/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1079 - accuracy: 0.9762
# Epoch 40/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1027 - accuracy: 0.9700
# Epoch 41/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1012 - accuracy: 0.9700
# Epoch 42/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1067 - accuracy: 0.9638
# Epoch 43/50
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1013 - accuracy: 0.9725
# Epoch 44/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0979 - accuracy: 0.9762
# Epoch 45/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0975 - accuracy: 0.9725
# Epoch 46/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0962 - accuracy: 0.9700
# Epoch 47/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0919 - accuracy: 0.9700
# Epoch 48/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0958 - accuracy: 0.9700
# Epoch 49/50
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0940 - accuracy: 0.9712
# Epoch 50/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0888 - accuracy: 0.9725

# %%
plt.plot(history.epoch, history.history['accuracy'])

# %%
model_01.evaluate(X_test,Y_test)
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0910 - accuracy: 0.9700
# [0.09100690484046936, 0.9700000286102295]

# %%
import numpy as np
Y_predict = model_01.predict(X_test)
print(Y_predict.shape, Y_test.shape)
Y_predict = tf.math.round(tf.squeeze(Y_predict, axis=-1))
print(Y_predict[:10], Y_test[:10])
plt.scatter(np.arange(1,201), Y_predict - Y_test, marker='.')
# Out:
# (200, 1) (200,)
# tf.Tensor([1. 1. 1. 1. 0. 0. 1. 0. 1. 0.], shape=(10,), dtype=float32) [1 1 1 1 0 0 1 0 1 0]

# %%
x1 = np.linspace(-1.2, 1.2, 100)
y1 = np.linspace(-1.2, 1.2, 100)
xx, yy = np.meshgrid(x1, y1)
zz = np.c_[xx.ravel(), yy.ravel()]
z1 = model_01.predict(zz)
zzz = tf.reshape(z1,(100,100))
print(x1.shape, y1.shape, z1.shape, xx.shape, yy.shape, zz.shape, zzz.shape)

plt.contourf(x1, y1, zzz)

plt.scatter(x[:,0], x[:,1], marker='.', c=y, cmap=plt.cm.BuGn)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# (100,) (100,) (10000, 1) (100, 100) (100, 100) (10000, 2) (100, 100)
# Text(0, 0.5, 'y')
